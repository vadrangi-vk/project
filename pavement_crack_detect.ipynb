# %% [markdown]
# <a href="https://colab.research.google.com/github/vadrangi-vk/project/blob/main/pavement_crack_detect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.7/914.7 kB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 75.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 58.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 72.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# Install Roboflow
# !pip install roboflow ultralytics

# Import necessary libraries
from roboflow import Roboflow
from ultralytics import YOLO
import os

# Download dataset from Roboflow
rf = Roboflow(api_key="nITGKLtXs24Pwq4gcn7J")
project = rf.workspace("vadrangi-vishal-kumar").project("crack-detection-mwoxx")
version = project.version(1)
dataset = version.download("yolov11")

# Change directory to where your dataset and images are stored
new_path = "/content/drive/MyDrive/Colab Notebooks"
os.chdir(new_path)

# Load the YOLOv11 model
model = YOLO("yolov8n.pt")  # Ensure you have the correct model file

# Train the model using the downloaded dataset
model.train(data=f"{dataset.location}/data.yaml", epochs=20, imgsz=640, workers=4)
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Ultralytics 8.3.74 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# 🔹 Load the trained YOLO model
weights_path = "/content/drive/MyDrive/Colab Notebooks/runs/detect/train4/weights/best.pt"  # Adjust if needed
model = YOLO(weights_path)

# ✅ Run inference on a test image
image_path = "/content/drive/MyDrive/Colab Notebooks/00535.jpg"  # Provide the correct path to the image
results = model.predict(image_path, save=True)  # Save predictions

# 🔹 Locate the saved inference image
output_image_path = "/content/drive/MyDrive/Colab Notebooks/runs/detect/predict/00535.jpg"  # Adjust saved image name

# ✅ Display the detected image using Matplotlib
image = cv2.imread(output_image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for Matplotlib

plt.figure(figsize=(8, 6))
plt.imshow(image)
plt.axis("off")  # Hide axes
plt.title("Crack Detection Results")
plt.show()
# Out:
# image 1/1 /content/drive/MyDrive/Colab Notebooks/00535.jpg: 640x640 1 crack, 7.9ms
# Speed: 3.1ms preprocess, 7.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
